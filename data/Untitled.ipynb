# %%
from zipfile import ZipFile

# %%
with ZipFile('data/stridsmeldinger.zip') as sm_zip:
    print(sm_zip)
# Out:
# ------------------------------------------------------------
# FileNotFoundError          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with ZipFile('data/stridsmeldinger.zip') as sm_zip:
#       2     print(sm_zip)
#
# File ~\anaconda3\envs\kurs\lib\zipfile.py:1251, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249 while True:
#    1250     try:
# -> 1251         self.fp = io.open(file, filemode)
#    1252     except OSError:
#    1253         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/stridsmeldinger.zip'
