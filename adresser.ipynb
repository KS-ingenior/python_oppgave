# %%
import pandas as pd
import geopandas as gpd

from geopy.geocoders import Nominatim
from ipyleaflet import Map, GeoData, basemaps, LayersControl

geolocator = Nominatim(user_agent="Python-kurs-2024")

# %%
# Read csv without headers, set column names manually.
df = pd.read_csv(
    'data/adresser.txt',
    header=None,
    names=['adresse', 'postnr_sted', 'land']
)

# %%
# Invoke geocoder on 'adresse' and 'postnr/sted'
df['geocode_res'] = df.apply(
    lambda x: geolocator.geocode(x['adresse'] + ', ' + x['postnr_sted']),
    axis=1
)

# %%
# Fetch lat/long from geocoder result
df['lat'] = df['geocode_res'].apply(lambda x: x.latitude)
df['lon'] = df['geocode_res'].apply(lambda x: x.longitude)

# %%
# Convert dataframe into geodataframe, converting latlon into proper points.
gdf = gpd.GeoDataFrame(
    df[['adresse', 'postnr_sted', 'land']],
    geometry=gpd.points_from_xy(df['lon'], df['lat'])
)

# %%
m = Map(
    basemap=basemaps.OpenStreetMap.Mapnik,
    center=(59.91228, 10.78560),
    zoom=10
)

geo_data = GeoData(geo_dataframe = gdf,
    name = 'addresser')

m.add(geo_data)
m.add(LayersControl())

m
# Out:
# Map(center=[59.91228, 10.7856], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
gdf
# Out:
#                   adresse postnr_sted    land                   geometry
# 0        Kampen hageby 21   0655 Oslo   Norge  POINT (10.78560 59.91228)
# 1         Dybwads gate 4A   0367 Oslo   Norge  POINT (10.71684 59.92575)
# 2         Oscars gate 35B   0258 Oslo   Norge  POINT (10.72378 59.92084)
# 3        Colletts gate 88   0460 Oslo   Norge  POINT (10.75184 59.93355)
# 4          Slåmotgangen 2   0186 Oslo   Norge  POINT (10.76134 59.91672)
# 5  Brynjulf Bulls plass 1   0250 Oslo   Norge  POINT (10.73048 59.91161)
# 6            Njåls vei 16   0576 Oslo   Norge  POINT (10.78644 59.91897)
# 7         Sinsenveien 62C   0586 Oslo   Norge  POINT (10.79134 59.93589)
# 8            Fossefaret 6   0373 Oslo   Norge  POINT (10.71204 59.94052)
# 9       Malerhaugveien 33   0661 Oslo   Norge  POINT (10.79646 59.91643)
